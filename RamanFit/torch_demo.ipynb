# %%
import numpy as np
from fit_func import load_helper
from torch_fit import one_peak_map_fit, two_peak_map_fit
import matplotlib.pyplot as plt

# %%
x_input, y_input = load_helper('spectrums.txt')

# %%
si_params = one_peak_map_fit(x_input, y_input[:,:,:])
params = two_peak_map_fit(x_input, y_input[:,:,:])
# Out:
# Apple M series GPU accelaration enabled.
#   0%|          | 0/250 [00:00<?, ?it/s]/Users/ycn/anaconda3/lib/python3.11/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# Loss 468.830420992 : 100%|██████████| 250/250 [00:03<00:00, 65.19it/s]
# Apple M series GPU accelaration enabled.
# Loss 86.018588672 : 100%|██████████| 250/250 [00:08<00:00, 28.77it/s]

# %%
plt.imshow(params['peak_0_centers'])
