# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('temprature_record.npy')[:1415]

# %%
fig, ax = plt.subplots()

ax2 = ax.twinx()
ax.plot(data[:-1], color='blue')
ax2.plot(np.diff(data), color='red')
