# %%
from functools import partial
import numpy as np
from scipy.optimize import root_scalar, minimize, newton, root_scalar, brentq
import nidaqmx as ni
from K10CR1 import K10CR1_stage

def read_daq_output(DAQ_name='Dev2'):

    with ni.Task() as read_task:
        
    
        read_task.ai_channels.add_ai_voltage_chan(DAQ_name + "/ai0",
                                    min_val=-10, max_val=10)
        result = np.array(read_task.read())
    return result

def read_detector(rotator, angle):

    residual_anle = angle % 360
    rotator.move(float(angle))
    value = read_daq_output()
    return value

# %%
polarizer = K10CR1_stage(serial_no=55422054)
polarizer.initialize_instrument()
polarizer.home_device()



HWP = K10CR1_stage(serial_no=55425654)
HWP.initialize_instrument()
HWP.home_device()
HWP.move(180)

HWP_angles = []

initial_guess = 180

guess = initial_guess
# Out:
# Important: make sure you are not running Kinesis softeare in the meantime.
# Otherwise the initialization will fail.
# K10CR1 Rotational Stage
# Homing the rotation stage of SN:  55422054
# The system is at home position. This position will be referred as 0 degree.
# Important: make sure you are not running Kinesis softeare in the meantime.
# Otherwise the initialization will fail.
# K10CR1 Rotational Stage
# Homing the rotation stage of SN:  55425654
# The system is at home position. This position will be referred as 0 degree.
# Moving the rotation stage of SN: 55425654 to 180 degrees
# Movement finished.

# %%
# for angle in np.linspace(0,360, num=361):
#     polarizer.move(angle)
#     zero_angle = newton(partial(read_detector, HWP), 
#                       guess, maxiter=50)
#     HWP_angles.append(zero_angle)
#     guess = zero_angle

# %%
read_daq_output()
# Out:
# array(0.2052462)

# %%
HWP.move(180)
# Out:
# Moving the rotation stage of SN: 55425654 to 180 degrees
# Movement finished.

# %%
read_daq_output()
# Out:
# array(-0.06401888)

# %%
polarizer.move(250)
# HWP.move(170)
# Out:
# Moving the rotation stage of SN: 55422054 to 250 degrees
# Movement finished.

# %%
# zero_angle = newton(partial(read_detector, HWP), 
#                       180, maxiter=50, tol=0.0001)
zero_angle = brentq(partial(read_detector, HWP), 
                      0, 90)
# Out:
# Moving the rotation stage of SN: 55425654 to 0 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 90 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 22.06539 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.8475202 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.4746051 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3295882 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.309277 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3272583 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.32892 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3294604 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.329579 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3295875 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3295881 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3295882 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3295882 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3295882 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3295882 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3295882 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3295882 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3295882 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3295882 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3295882 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0.3295882 degrees
# Movement finished.

# %%
for angle in np.linspace(0,360, num=90):
    polarizer.move(angle)
    # results2.append(read_daq_output())

# %%
polarizer.move(0)
results2 = []
for angle in np.linspace(0,360, num=90):
    HWP.move(angle)
    results2.append(read_daq_output())
# Out:
# Moving the rotation stage of SN: 55422054 to 0 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 0 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 4.044944 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 8.089888 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 12.13483 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 16.17978 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 20.22472 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 24.26966 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 28.31461 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 32.35955 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 36.4045 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 40.44944 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 44.49438 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 48.53933 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 52.58427 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 56.62922 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 60.67416 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 64.7191 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 68.76405 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 72.80899 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 76.85394 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 80.89888 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 84.94382 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 88.98876 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 93.03371 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 97.07865 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 101.1236 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 105.1685 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 109.2135 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 113.2584 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 117.3034 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 121.3483 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 125.3933 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 129.4382 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 133.4831 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 137.5281 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 141.573 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 145.618 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 149.6629 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 153.7079 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 157.7528 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 161.7978 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 165.8427 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 169.8876 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 173.9326 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 177.9775 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 182.0225 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 186.0674 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 190.1124 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 194.1573 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 198.2022 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 202.2472 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 206.2921 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 210.3371 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 214.382 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 218.427 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 222.4719 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 226.5169 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 230.5618 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 234.6067 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 238.6517 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 242.6966 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 246.7416 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 250.7865 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 254.8315 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 258.8764 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 262.9214 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 266.9663 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 271.0112 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 275.0562 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 279.1011 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 283.1461 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 287.191 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 291.236 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 295.2809 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 299.3258 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 303.3708 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 307.4157 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 311.4607 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 315.5056 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 319.5506 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 323.5955 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 327.6404 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 331.6854 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 335.7303 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 339.7753 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 343.8202 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 347.8652 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 351.9101 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 355.955 degrees
# Movement finished.
# Moving the rotation stage of SN: 55425654 to 360 degrees
# Movement finished.

# %%
import matplotlib.pyplot as plt

# %%
results2 = np.array(results2).reshape(-1)

# %%
plt.plot((results))
plt.plot((results2))

# %%
res1= results

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'polar'})
ax.plot(np.linspace(0,2*np.pi, num=90), (results))
ax.plot(np.linspace(0,2*np.pi, num=90), (results2))
